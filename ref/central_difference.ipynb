# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def my_central_diff(x,h): 
    central_diff=np.zeros((len(x))-2)
    for i in range(len(x)-2):
            central_diff[i]=((x[i+2]-x[i])/(2*h)) #計算central_diff
    return central_diff

# %%
plt.style.use("seaborn-poster")
get_ipython().run_line_magic('matplotlib', 'inline')

h = 0.1
x = np.arange(0, 2*np.pi, h)#x軸範圍從0到2pi
y = np.cos(x)#f(x)=cos(x)

# compute vector central differences
central_diff = my_central_diff(y,h)

# compute corresponding grid
x_diff = x[1:-1:]

# compute exact solution
exact_solution = -np.sin(x_diff)

# Plot solution
plt.figure(figsize = (12, 8))
plt.plot(x_diff, central_diff, label = "Finite difference approximation",linewidth=8)
plt.plot(x_diff, exact_solution, label = "Exact solution",linewidth=4)
plt.legend()
plt.show()

# Compute max error between
# numerical derivative and exact solution
max_error = max(abs(exact_solution - central_diff))
print('The maximum error is',max_error)
# Out:
# The maximum error is 0.0016657056915946322
